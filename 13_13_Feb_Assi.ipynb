# %% [markdown]
# ## Data Science Masters - Hindi - 13 Feb 2023

# %% [markdown]
# #### Q1. Explain why we have to use the Exception class while creating a Custom Exception.

# %% [markdown]
# - The exception class is like the super class for all exceptions.. when we create an custom exception we inherit the properties of exception class

# %% [markdown]
# #### Q2. Write a python program to print Python Exception Hierarchy.

# %%
# Program to find Exception Hierarchy

import inspect
from logging import *

LOG_FROMAT = "%(lineno)s * %(name)s * %(asctime)s * %(levelname)s * %(message)s"
basicConfig(filename="13_1_Feb.log", level=INFO, format=LOG_FROMAT)


def treeClass(cls, ind=0):

    str1 = "-"*ind
    str2 = cls.__name__
    info('%s %s', str1, str2)

    for i in cls.__subclasses__():
        treeClass(i, ind + 1)


info("Python Exception hierarchy is : ")

inspect.getclasstree(inspect.getmro(BaseException))

treeClass(BaseException)

shutdown()

with open("13_1_Feb.log") as f:
    print(f.read())
# Out:
# 20 * root * 2023-02-15 14:48:29,742 * INFO * Python Exception hierarchy is :
# 14 * root * 2023-02-15 14:48:29,742 * INFO *  BaseException
# 14 * root * 2023-02-15 14:48:29,743 * INFO * - Exception
# 14 * root * 2023-02-15 14:48:29,743 * INFO * -- TypeError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * --- FloatOperation
# 14 * root * 2023-02-15 14:48:29,743 * INFO * --- MultipartConversionError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * -- StopAsyncIteration
# 14 * root * 2023-02-15 14:48:29,743 * INFO * -- StopIteration
# 14 * root * 2023-02-15 14:48:29,743 * INFO * -- ImportError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * --- ModuleNotFoundError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * ---- PackageNotFoundError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * --- ZipImportError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * -- OSError
# 14 * root * 2023-02-15 14:48:29,743 * INFO * --- ConnectionError
# 14 * root * 2023-02-15 14:48:29,744 * INFO * ---- BrokenPipeError
# ...

# %% [markdown]
# #### Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

# %% [markdown]
# Python ArithmeticError hierarchy is :
# - ArithmeticError
# #
# -- FloatingPointError
# #
# -- OverflowError
# #
# -- ZeroDivisionError
# #
# --- DivisionByZero
# #
# --- DivisionUndefined
# #
# -- DecimalException
# #
# --- Clamped
# #
# --- InvalidOperation
# #
# ---- ConversionSyntax
# #
# ---- DivisionImpossible
# #
# ---- DivisionUndefined
# #
# ---- InvalidContext
# #
# --- DivisionByZero
# #
# --- Inexact
# #
# ---- Overflow
# #
# ---- Underflow
# #
# --- Rounded
# #
# ---- Overflow
# #
# ---- Underflow
# #
# --- Subnormal
# #
# ---- Underflow
# #
# --- FloatOperation

# %% [markdown]
# - Examples :
#     - 1. ZeroDivisionError
#         - Second argument to a division or modulo operation is zero.

# %%
# ZeroDivisionError

5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 # ZeroDivisionError
# ----> 3 5/0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# - 2. OverflowError
#     - When the result of an arithmetic operation is too large to be represented.

# %%
# OverflowError

n = 10.0

n **= 1000
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[2], line 5
#       1 # OverflowError
#       3 n = 10.0
# ----> 5 n **= 1000
#
# OverflowError: (34, 'Numerical result out of range')

# %%
# Program to find Arithmetic Error Hierarchy

import inspect
from logging import *

LOG_FROMAT = "%(message)s"
basicConfig(filename="13_2_Feb.log", level=INFO, format=LOG_FROMAT)


def treeClass(cls, ind=0):

    str1 = "-"*ind
    str2 = cls.__name__
    info('%s %s', str1, str2)
    info('#')
    # print(str1, "*", str2)

    for i in cls.__subclasses__():
        treeClass(i, ind + 1)


info("Python ArithmeticError hierarchy is : ")

inspect.getclasstree(inspect.getmro(BaseException))

treeClass(ArithmeticError)

shutdown()

with open("13_2_Feb.log") as f:
    print(f.read())
# Out:
# Python ArithmeticError hierarchy is :
#  ArithmeticError
# #
# - FloatingPointError
# #
# - OverflowError
# #
# - ZeroDivisionError
# #
# -- DivisionByZero
# #
# -- DivisionUndefined
# #
# - DecimalException
# #
# -- Clamped
# #
# -- InvalidOperation
# #
# --- ConversionSyntax
# #
# --- DivisionImpossible
# #
# --- DivisionUndefined
# #
# --- InvalidContext
# #
# -- DivisionByZero
# #
# -- Inexact
# #
# --- Overflow
# #
# --- Underflow
# #
# -- Rounded
# #
# --- Overflow
# #
# --- Underflow
# #
# -- Subnormal
# #
# --- Underflow
# #
# -- FloatOperation
# #

# %% [markdown]
# #### Q4. Why LookupError class is used? Explain with an example KeyError and IndexError.

# %% [markdown]
# - Lookup Error is the base class for the exceptions that occur when a key or index used on a mapping or sequence of a list/dictionary is invalid or does not exists.

# %% [markdown]
# - KeyError
#     - It arises when a key used to access a dictionaty item that is not present in the dictionary.

# %%
d = {
    "name": "Aditya",
    "roll": 123
}

d[4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 6
#       1 d = {
#       2     "name": "Aditya",
#       3     "roll": 123
#       4 }
# ----> 6 d[4]
#
# KeyError: 4

# %% [markdown]
# - IndexError
#     - When we try to access an index that is out of range in the given iterable.

# %%
l = ["Aditya", "Azad", "Data", "Science"]
l[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 l = ["Aditya", "Azad", "Data", "Science"]
# ----> 2 l[5]
#
# IndexError: list index out of range

# %% [markdown]
# #### Q5. Explain ImportError. What is ModuleNotFoundError?

# %% [markdown]
# - ImportError
#     - When a class cannot be imported from a module due to unavailability or circular dependency.

# %%
# Import Error

from numpy import pro
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 # Import Error
# ----> 3 from numpy import pro
#
# ImportError: cannot import name 'pro' from 'numpy' (/usr/lib/python3.10/site-packages/numpy/__init__.py)

# %% [markdown]
# - ModuleNotFoundError
#     - This error arises when the specified module/package is not found in the installed python library or invalid path.

# %%
# ModuleNotFoundError

import nump
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 # ModuleNotFoundError
# ----> 3 import nump
#
# ModuleNotFoundError: No module named 'nump'

# %% [markdown]
# #### Q6. List down some best practices for exception handling in python.

# %% [markdown]
# - Don't use generic exception
# - Use a specific exception class
# - Use a specific message
# - Give a specific cause
# - Use try-catch block to also recover resources.
# - Apply exception handlers to only those blocks of statements that might throw an exception.
# - Don't use too many exception handlers.
# - Use Context Managers to simplify repetitive exception handling logic
